# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Hello, Tom!</b> We're glad to see you in code-reviewer territory. You've done a great job on the project, but let's get to know each other and make it even better! We have our own atmosphere here and a few rules:
#
#
# 1. I work as a code reviewer, and my main goal is not to point out your mistakes, but to share my experience and help you become a data analyst.
# 2. We speak on a first-come-first-served basis.
# 3. if you want to write or ask a question, don't be shy. Just choose your color for your comment.
# 4. this is a training project, you don't have to be afraid of making a mistake.
# 5. You have an unlimited number of attempts to pass the project.
# 6. Let's Go!
#
#
# ---
# I'll be color-coding comments, please don't delete them:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №1__
#
# Needs fixing. The block requires some corrections. Work can't be accepted with the red comments.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Reviewer's comment №1__
#
#
# Remarks. Some recommendations.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Reviewer's comment №1__
#
# Success. Everything is done succesfully.
# </div>
#
# ---
#
# I suggest that we work on the project in dialogue: if you change something in the project or respond to my comments, write about it. It will be easier for me to track changes if you highlight your comments:
#
# <div class="alert alert-info"> <b>Student сomments:</b> Student answer..</div>
#
# All this will help to make the recheck of your project faster. If you have any questions about my comments, let me know, we'll figure it out together :)
#
# ---

# %% [markdown]
# The purpose of the project is to sort and clean data in the Instacart data files. As well as to prepare a report of what the habits are of the customers.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №1__
#
# in markdown please ![image.png](attachment:image.png)

# %% [markdown]
# Start by importing libraries and csv files. Then fixing files if needed so that they can be read

# %%
# 1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_insta_orders= pd.read_csv('/datasets/instacart_orders.csv', sep= ';')
df_insta_orders.info()
print()
df_insta_orders.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Reviewer's comment №1__
#
#
# I suggest separating logically different things:
#
#     - library imports
#     - data opening (this may not be a trivial process)
#     - working code
#
# This approach will improve code readability, reduce the time of searching for errors, if there are any, and exclude code re-execution
# </div>

# %% [markdown]
# We can confirm that the ID columns are integers as the dtype for those columns are called as such for the orders.

# %%
df_products= pd.read_csv('/datasets/products.csv', sep= ';')
df_products.info()
df_products.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# ...

# %% [markdown]
# We can confirm that the ID columns are integers as the dtype for those columns are called as such for the products.

# %%
df_aisles= pd.read_csv('/datasets/aisles.csv', sep=';')
df_aisles.info()
df_aisles.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %% [markdown]
# We can confirm that the ID columns are integers as the dtype for those columns are called as such for the aisles.

# %%
df_dep= pd.read_csv('/datasets/departments.csv', sep= ';')
df_dep.info()
df_dep.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %% [markdown]
# We can confirm that the ID columns are integers as the dtype for those columns are called as such for the departments.

# %%
df_order_products= pd.read_csv('/datasets/order_products.csv', sep=';')
df_order_products.info(show_counts=True)
df_order_products.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB
#    order_id  product_id  add_to_cart_order  reordered
# 0   2141543       11440               17.0          0
# 1    567889        1560                1.0          1
# 2   2261212       26683                1.0          1
# 3    491251        8670               35.0          1
# 4   2571142        1940                5.0          1

# %% [markdown]
# We can confirm that the ID columns are integers as the dtype for those columns are called as such for the products.
# We have confirmed for all of the csv files that the IDs are all in integer form as requested.
# We also hav emade the files legible to read by making the seperator, sep=, a ;.

# %% [markdown]
# Step two is to clean the data for each df. Starting with the orders.
# From the info() we have found that one column has missing values: days_since_prior_order and it's labeled as dtype Float

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Reviewer's comment №1__
#
# All right

# %%
# 1.1
display(df_insta_orders['days_since_prior_order'].isna().sum())
print('______')
display(df_insta_orders['days_since_prior_order'].value_counts(dropna=False))
# Out:
# 28819
# ______
# 30.0    51338
# 7.0     44579
# 6.0     33931
# 4.0     31007
# 3.0     30225
# 5.0     30096
# NaN     28819
# 2.0     27141
# 8.0     25361
# 1.0     20179
# 9.0     16754
# 14.0    13992
# 10.0    13310
# 13.0    11737
# 11.0    11467
# 12.0    10658
# 0.0      9589
# 15.0     9416
# 16.0     6588
# 21.0     6448
# 17.0     5498
# 20.0     5302
# 18.0     4972
# 19.0     4939
# 22.0     4514
# 28.0     3745
# 23.0     3337
# 24.0     3015
# 27.0     2986
# 25.0     2711
# 29.0     2673
# 26.0     2640
# Name: days_since_prior_order, dtype: int64

# %% [markdown]
# I have confirmed the missing values in the data, 28819
# Using fillna() to replace any Nan values with Unknown or first time and seeing if that satisfies the missing values
# using -1 to keep the dtype the same rather than object

# %%
df_insta_orders['days_since_prior_order']= df_insta_orders['days_since_prior_order'].fillna(-1)
display(df_insta_orders['days_since_prior_order'].isna().sum())
print('______')
display(df_insta_orders['days_since_prior_order'].value_counts(dropna=False))
# Out:
# 0
# ______
#  30.0    51338
#  7.0     44579
#  6.0     33931
#  4.0     31007
#  3.0     30225
#  5.0     30096
# -1.0     28819
#  2.0     27141
#  8.0     25361
#  1.0     20179
#  9.0     16754
#  14.0    13992
#  10.0    13310
#  13.0    11737
#  11.0    11467
#  12.0    10658
#  0.0      9589
#  15.0     9416
#  16.0     6588
#  21.0     6448
#  17.0     5498
#  20.0     5302
#  18.0     4972
#  19.0     4939
#  22.0     4514
#  28.0     3745
#  23.0     3337
#  24.0     3015
#  27.0     2986
#  25.0     2711
#  29.0     2673
#  26.0     2640
# Name: days_since_prior_order, dtype: int64

# %% [markdown]
# We replaced the NaN values with Unknown as we do not know the amount of days since the last order.
# As there is a row for 0, which indicates less than a a day since the last order, we cannot fill in our data with 0.
# also because there is a certain amount of time between each order it is inappropriate to simply drop the missing values.
# That is why I changed the times with missing values to -1 as there is some time between orders but it is unknown to us
# It is also possible that the this is the first order this person made so therefore there isn't a prior time they ordered

# %%
#checking if the values are filled
df_insta_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  478967 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %% [markdown]
# There may be duplicates in either order_number or order_id as these shouldn't have duplicates
# it is okay if user_id has duplicate values as that indicates a user ordering multiple times
# order_hour_of_day is also fine because time of day will repeat. Same with days_since_prior_order.
# order_dow stands for day of week, however needed to search web for this so decided to chang to make it clear

# %%
df_insta_orders.rename(columns={'order_dow':'order_day_of_week'},inplace=True)
df_insta_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_day_of_week       478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  478967 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %%
# checking total duplicates using the duplicated().sum() methods in conjuction
df_insta_orders.duplicated().sum()
# Out:
# 15

# %%
#checking order_id for duplicates. We know we have 15 repeats so using head(16) makes sense to see if there is 15 repeats
df_insta_orders['order_id'].value_counts().head(16)
# Out:
# 2125197    2
# 1782114    2
# 1286742    2
# 391768     2
# 1021560    2
# 2232988    2
# 408114     2
# 2282673    2
# 1919531    2
# 2160484    2
# 1918001    2
# 794638     2
# 1112182    2
# 467134     2
# 2845099    2
# 2357032    1
# Name: order_id, dtype: int64

# %%
# order_id seems to have 15 duplicates just like the total amount of duplicates
df_insta_orders=df_insta_orders.drop_duplicates(subset='order_id')
total_duplicates= df_insta_orders.duplicated().sum()
duplicates_order_id= df_insta_orders['order_id'].duplicated().sum()
print(f'Total duplicates in df:{total_duplicates}')
print()
print(f'Number of duplicates in order_id: {duplicates_order_id}')
print()
df_insta_orders.info()
# Out:
# Total duplicates in df:0
#
# Number of duplicates in order_id: 0
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478952 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478952 non-null  int64
#  1   user_id                 478952 non-null  int64
#  2   order_number            478952 non-null  int64
#  3   order_day_of_week       478952 non-null  int64
#  4   order_hour_of_day       478952 non-null  int64
#  5   days_since_prior_order  478952 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 25.6 MB

# %% [markdown]
# I found out that there were 15 duplicated items in the whole df by calling duplicated().sum() on the df
# I then went through the columns to find which column had the duplicates in this case order_id
# Because a single order should not have multiple I elected to drop those orders from order_id
# Then I confirmed that we got rid of the duplicates from the df
# checking for orders made on a wednesday at 2pm

# %%
df_wed_2am= df_insta_orders[(df_insta_orders['order_day_of_week']== 3) & (df_insta_orders['order_hour_of_day']== 2)]
display(df_wed_2am)
# where hour_of_day starts at 0 or 12:00 am 1:00 am is 1 and 2am is 2
# Out:
#         order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 4838     2766110   162084            41                  3                  2
# 5156     2190225   138285            18                  3                  2
# 15506     553049    58599            13                  3                  2
# 18420     382357   120200            19                  3                  2
# 24691     690242    77357             2                  3                  2
# ...          ...      ...           ...                ...                ...
# 457013   3384021    14881             6                  3                  2
# 458816    910166   164782            18                  3                  2
# 459635   1680532   106435             6                  3                  2
# 468324    222962    54979            59                  3                  2
# 477526   2592344    46860            38                  3                  2
#
#         days_since_prior_order
# ...

# %% [markdown]
# To recap, the reason for the missing values in days since prior order may be due to the fact that they never ordered before
# Another reason is that the number of days exceeds the count for that column or another unknown reason
# As for the duplicates, there's the possiblity that there was a return or replacement and was filed under the same order
# the data was processed multiple times by error or the order was locked into processing and never completed

# %% [markdown]
# Repeating process for missing and duplicates for the other dfs
# 1.5 checking order products

# %%
df_order_products.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %%
# missing values in add_to_cart_order
df_order_products.isnull().sum()
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# trying to see where the missing values are
df_order_products['add_to_cart_order'].value_counts(dropna=False)
# Out:
# 1.0     450046
# 2.0     428199
# 3.0     401907
# 4.0     372861
# 5.0     341807
#          ...
# 60.0       127
# 61.0       114
# 62.0        98
# 63.0        87
# 64.0        75
# Name: add_to_cart_order, Length: 65, dtype: int64

# %% [markdown]
# Replacing the null values as they account for a very small portion of the data'
# It is likly that the missing values were items that were never added to the cart but were recorded by instacart
# again making the fillna -1 to keep the dtype the same

# %%
df_order_products['add_to_cart_order']= df_order_products['add_to_cart_order'].fillna(-1)

# %%
# double checking that the values are not missing anymore
df_order_products.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4545007 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %% [markdown]
# 1.2 df_products

# %%
df_products.info()
display(df_products.head())
print()
display(df_products.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# ...

# %%
df_products['product_id'].duplicated().sum()
# Out:
# 0

# %%
df_products['product_id'].value_counts(dropna=False)
# Out:
# 2049     1
# 693      1
# 4759     1
# 27288    1
# 25241    1
#         ..
# 9550     1
# 11599    1
# 38232    1
# 40281    1
# 2047     1
# Name: product_id, Length: 49694, dtype: int64

# %% [markdown]
# Checking for duplicate products that aren't nan values and then dropping them

# %%
df_products['product_name']= df_products['product_name'].str.lower()
df_products['product_name'].value_counts(dropna=False)
# Out:
# NaN                                             1258
# green tea with ginseng and honey                   3
# sea salt caramel ice cream                         2
# bleu cheese salad dressing and dip                 2
# anchovy fillets in olive oil                       2
#                                                 ...
# organic whole wheat pie 9\" shells 2 ct            1
# zero calorie sport drink                           1
# cabernet sauvignon napa valley                     1
# frozen concentrate non-alcoholic pina colada       1
# multi-grain club crackers                          1
# Name: product_name, Length: 48333, dtype: int64

# %%
df_products['product_name']= df_products['product_name'].drop_duplicates()
df_products['product_name'].value_counts(dropna=False)
# Out:
# NaN                                      1362
# mexican style rice & pasta                  1
# dark chocolate 72% cacao                    1
# soap- pure coconut milk                     1
# antioxidant infusions molokai coconut       1
#                                          ...
# broccoli medley                             1
# peppermint 16 pieces sugar free gum         1
# deluxe american cheese slices               1
# country ham biscuit slices                  1
# multi-grain club crackers                   1
# Name: product_name, Length: 48333, dtype: int64

# %% [markdown]
# Dropping missing values with fillna and replacing with Unknown as we do not know the name of the product

# %%
df_products['product_name']= df_products['product_name'].fillna('Unknown')
df_products['product_name'].value_counts(dropna=False)
# Out:
# Unknown                                  1362
# high heat canola spray oil                  1
# mexican style rice & pasta                  1
# soap- pure coconut milk                     1
# antioxidant infusions molokai coconut       1
#                                          ...
# peppermint 16 pieces sugar free gum         1
# deluxe american cheese slices               1
# country ham biscuit slices                  1
# vitamin b-12 1000 mcg                       1
# multi-grain club crackers                   1
# Name: product_name, Length: 48333, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Reviewer's comment №1__
#
# You chose the most correct way to replace the omissions in the categorical column. Well done!)

# %%
# checking further into what the nan values looked like
df_products.query('product_name=="Unknown"')
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38      Unknown       100             21
# 71             72      Unknown       100             21
# 109           110      Unknown       100             21
# 296           297      Unknown       100             21
# 416           417      Unknown       100             21
# ...           ...          ...       ...            ...
# 49689       49690      Unknown        64              7
# 49690       49691      Unknown       130             14
# 49691       49692      Unknown       130             14
# 49692       49693      Unknown       127             11
# 49693       49694      Unknown        38              1
#
# [1362 rows x 4 columns]

# %% [markdown]
# 1.3 departments

# %%
df_dep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %%
display(df_dep)
# Out:
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing

# %% [markdown]
# Departments looks good and no need for anything to be done

# %% [markdown]
# 1.4 aisles

# %%
df_aisles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
df_aisles.head(10)
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation
# 5         6                       other
# 6         7               packaged meat
# 7         8             bakery desserts
# 8         9                 pasta sauce
# 9        10            kitchen supplies

# %% [markdown]
# Everything looks good with this data as well

# %% [markdown]
# 2.1 reviewing and processing data for df_product. Starting with checking if the nan values are all in aisle 100

# %%
df_products.query('product_name=="Unknown"')
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38      Unknown       100             21
# 71             72      Unknown       100             21
# 109           110      Unknown       100             21
# 296           297      Unknown       100             21
# 416           417      Unknown       100             21
# ...           ...          ...       ...            ...
# 49689       49690      Unknown        64              7
# 49690       49691      Unknown       130             14
# 49691       49692      Unknown       130             14
# 49692       49693      Unknown       127             11
# 49693       49694      Unknown        38              1
#
# [1362 rows x 4 columns]

# %% [markdown]
# We can see from this query that not all of the nan values are from aisle 100 or that department 21 isn't responsible for all missing values. I have already changed the nan values to unknown for df_products.
# Before moving on to step 3 we will check if each df has all the values accounted for

# %%
df_insta_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478952 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478952 non-null  int64
#  1   user_id                 478952 non-null  int64
#  2   order_number            478952 non-null  int64
#  3   order_day_of_week       478952 non-null  int64
#  4   order_hour_of_day       478952 non-null  int64
#  5   days_since_prior_order  478952 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 25.6 MB

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   49694 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
df_dep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %%
df_aisles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
df_order_products.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4545007 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %% [markdown]
# looks like we changed all the values so that the data is filled in
# Step 3-A-1 and checking the range of the hour of day and day of week columns

# %%
print("Order Hour of Day Range:", df_insta_orders['order_hour_of_day'].min(), "-", df_insta_orders['order_hour_of_day'].max())
print("Order Day of Week Range:", df_insta_orders['order_day_of_week'].min(), "-", df_insta_orders['order_day_of_week'].max())
# Out:
# Order Hour of Day Range: 0 - 23
# Order Day of Week Range: 0 - 6

# %% [markdown]
# 3-A-2 Create a plot that shows how many people place orders for each hour of the day.

# %%
order_counts= df_insta_orders['order_hour_of_day'].value_counts().sort_index()

order_counts.plot(
    x='order_hour_of_day',  
    y='num_orders',         
    kind='bar', 
    figsize=(10,6),
    title='Number of Orders by Hour of Day',
    xlabel='Hour of Day',
    ylabel='Number of Orders',
    legend=False,
    color='skyblue',
    rot= 30
)

plt.xticks(range(24))  
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №1__
#
# It is better after each section, graph (or series of tests) to write a conclusion on the obtained data taking into account the set business task - so it is easier to read the project, because future colleagues or customers will not have to interpret the results of each section, test or graph themselves.
#
# In markdown cell ![image.png](attachment:image.png)

# %% [markdown]
# From this data, we can see that the peak ordering times occur between 9 AM and 4 PM. Before 9 AM, order volume gradually increases, while after 4 PM, it steadily declines.

# %% [markdown]
# 3-A-3 Create a plot that shows what day of the week people shop for groceries.

# %%
orders_day= df_insta_orders['order_day_of_week'].value_counts().sort_index()
orders_day.plot(
    kind='bar',
    figsize=(10,6),
    xlabel='Day of the Week',
    ylabel= 'Number of Orders',
    legend= False,
    color= 'forestgreen',
    title= 'Number of Orders by the Day of Week',
    rot=30,
)
plt.show()

# %% [markdown]
# Orders seem to happen more frequently on Sunday and Monday, if we assume that 0 is Sunday and 1 is Monday. By around 15000 orders.

# %% [markdown]
# 3-A-4 Create a plot that shows how long people wait until placing their next order, and comment on the minimum and maximum values.

# %%
reorders= df_insta_orders['days_since_prior_order'].value_counts().sort_index()
reorders.plot(kind='bar',
             figsize=(10,6),
             xlabel= 'Days Since Prior Order',
             ylabel= 'Number of Orders',
             color= 'teal',
             rot= '30',
             title= 'Days Between Orders',
             legend=False,
             xlim=(0,100))
plt.show()

# %% [markdown]
# It is likely that the -1 days that we converted from the nan values are 1st time orders or errors
# 0 days likely means they ordered less than a day ago, probably meaning they forgot something on the first time around
# 7 days is the spike which makes since because of weekly purchases
# 30 days has a spike because either the days were in fact 30 days apart, but also that it could be 30+ days meaning longer than
# I used xlim 100 to make sure that if there were higher values than 30 they would be registered

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Reviewer's comment №1__
#
# The 0 values probably correspond to customers who placed more than one order on the same day.

# %% [markdown]
# 3-B-1. Is there a difference in 'order_hour_of_day' distributions on Wednesdays and Saturdays? Plot the histograms for both days on the same plot and describe the differences that you see.
# Where 0 for day of week is sunday and 6 is saturday

# %%
wednesday_orders = df_insta_orders[df_insta_orders['order_day_of_week'] == 3]['order_hour_of_day']
saturday_orders = df_insta_orders[df_insta_orders['order_day_of_week'] == 6]['order_hour_of_day']


plt.figure(figsize=(10,6))

plt.hist(wednesday_orders, bins=24, alpha=0.5, color='royalblue', label='Wednesday', edgecolor='black')
plt.hist(saturday_orders, bins=24, alpha=0.5, color='forestgreen', label='Saturday', edgecolor='black')


plt.xlabel('Hour of Day')
plt.ylabel('Number of Orders')
plt.title('Order Distribution by Hour for Wednesday vs Saturday')
plt.legend()
plt.xticks(range(0, 24))  
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# It would appear that Saturday has more orders overall as it has overlapped Wednesday most of the time
# The busiest time of day is in the middle of the day between 9am and 4pm
# dispute Saturday having more orders the data is relatively close in terms of distribution
# This indicates that other days will likely also be busy during this time of day

# %% [markdown]
# 3-B-2 Plot the distribution for the number of orders that customers place (e.g. how many customers placed only 1 order, how many placed only 2, how many only 3, and so on…)

# %%
order_number = df_insta_orders['order_number'].value_counts().sort_index()
order_number.plot(xlabel= 'Number of Orders Placed',
                 ylabel= 'Number of Customers',
                 title= 'Number of Orders Per Customer',
                 color= 'seagreen',
                 figsize= (20,6),
                 kind='bar',
                 legend=False,
                 rot=60
                 )
plt.show()

# %% [markdown]
# From the results we can see that many are only first time buys and that there is a coorelation between the number of times
# an order is placed and how many people order. It would seem as the number of orders increase the number of customers decrease
# This means that either people do not use the app very frequently or that not enough time has passed for people to use the
# app frequently enough. If we could see multiple years in data we could see if the number of customers increase per
# number of order

# %% [markdown]
# 3-B-3 What are the top 20 products that are ordered most frequently (display their id and name)?

# %%
top_products = df_order_products['product_id'].value_counts().head(20)
top_products_df = top_products.reset_index()
top_products_df.columns = ['product_id', 'order_count']
top_products_df = top_products_df.merge(df_products[['product_id', 'product_name']], on='product_id', how='left')


print(top_products_df)
# Out:
#     product_id  order_count              product_name
# 0        24852        66050                    banana
# 1        13176        53297    bag of organic bananas
# 2        21137        37039      organic strawberries
# 3        21903        33971      organic baby spinach
# 4        47209        29773      organic hass avocado
# 5        47766        24689           organic avocado
# 6        47626        21495               large lemon
# 7        16797        20018              strawberries
# 8        26209        19690                     limes
# 9        27845        19600        organic whole milk
# 10       27966        19197       organic raspberries
# 11       22935        15898      organic yellow onion
# 12       24964        15292            organic garlic
# 13       45007        14584          organic zucchini
# 14       39275        13879       organic blueberries
# 15       49683        13675            cucumber kirby
# ...

# %% [markdown]
# Looks like banana is the top seller, with mostly produce also selling first before anything else.

# %% [markdown]
# 3-C-1 How many items do people typically buy in one order? What does the distribution look like?

# %%
items_per_order = df_order_products['order_id'].value_counts()

items_per_order.plot(
    kind='hist',
    bins=50,
    figsize=(10,6),
    xlabel='Number of Items per Order',
    ylabel='Number of Orders',
    title='Distribution of Items per Order',
    color='royalblue'
)
plt.show()


items_per_order.describe()
# Out:
# count    450046.000000
# mean         10.098983
# std           7.540206
# min           1.000000
# 25%           5.000000
# 50%           8.000000
# 75%          14.000000
# max         127.000000
# Name: order_id, dtype: float64

# %% [markdown]
# If we are looking at the median amount ordered 8 items per order. If we are looking at the mean, around 10 items an order.
# so most buy 8-10 items per order.

# %% [markdown]
# 3-C-5 What are the top 20 items that people put in their carts first (display the product IDs, product names, and number of times they were the first item added to the cart)?

# %%
first_item_counts = df_order_products[df_order_products['add_to_cart_order'] == 1]['product_id'].value_counts().head(20).reset_index()
first_item_counts.columns = ['product_id', 'first_added_count']

first_item_counts = first_item_counts.merge(df_products, on='product_id', how='left')

print(first_item_counts)
# Out:
#     product_id  first_added_count                 product_name  aisle_id  \
# 0        24852              15562                       banana        24
# 1        13176              11026       bag of organic bananas        24
# 2        27845               4363           organic whole milk        84
# 3        21137               3946         organic strawberries        24
# 4        47209               3390         organic hass avocado        24
# 5        21903               3336         organic baby spinach       123
# 6        47766               3044              organic avocado        24
# 7        19660               2336                 spring water       115
# 8        16797               2308                 strawberries        24
# 9        27966               2024          organic raspberries       123
# 10       44632               1914   sparkling water grapefruit       115
# 11       49235               1797          organic half & half        53
# ...

# %% [markdown]
# This indicates that people are likely to order their produce first before searching for other items they may want or need.

# %% [markdown]
# From this data we have found that people are likely to be first time buyers rather than continued ones.
# We have found that produce items are likely to be ordered first over other items.
# Customers order either 8 or 10 items per order normally.
# We found that bananas are the most ordered item
# We found that most orders happen between 9am-4pm
# we found that orders happen regularly by every 7 days. Also that there are many first time orders. That many orders happen
# after 30 days.
# Most orders happen on days 0 and 1, which this is an assumption, but 0 is Sunday and Monday is 1.

# %% [markdown]
# I also want to thank you for looking over the work and giving me feedback on how I can be better! Please let me know what else I can do to keep improving on my work I am very open to that.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Reviewer's comment №1__
#
#
# I agree, but conclusions should be written in a cell of type markdown
